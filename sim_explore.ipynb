# %%
import pandas as pd

# %%
sim_df = pd.read_csv("simdata.csv")

# %%
sim_df[[r"$\eta$", r"$\delta_r$", r"$\delta_s$"]]
# Out:
#          $\eta$  $\delta_r$  $\delta_s$
# 0     14.000000   -0.094361    0.114720
# 1     14.000000   -0.177194    0.097914
# 2     14.000000   -0.223383    0.008062
# 3     14.000000   -0.254395   -0.050065
# 4     14.000000   -0.275429   -0.087712
# ...         ...         ...         ...
# 2069   9.360172   -0.014823    0.040004
# 2070   9.360716   -0.014795    0.040026
# 2071   9.361258   -0.014767    0.040048
# 2072   9.361798   -0.014739    0.040070
# 2073   9.362336   -0.014711    0.040092
#
# [2074 rows x 3 columns]

# %%
sim_df.plot()

# %%
from utils.utils import plot_sim_df

plot_sim_df(sim_df, "./outputs")
# Out:
# IAE Cross track: 399.82959264101004, IAE Vertical track: 824.2967377750115
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
