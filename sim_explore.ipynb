# %%
import pandas as pd

# %%
sim_df = pd.read_csv("simdata.csv")

# %%
sim_df[[r"$\eta$", r"$\delta_r$", r"$\delta_s$"]]
# Out:
#          $\eta$  $\delta_r$  $\delta_s$
# 0     14.000000   -0.082926    0.174533
# 1     14.000000    0.003578    0.088002
# 2     14.000000    0.176918   -0.071507
# 3     14.000000    0.292479   -0.175527
# 4     14.000000    0.369519   -0.243483
# ...         ...         ...         ...
# 2128   9.754734    0.000873    0.091349
# 2129   9.755419    0.000871    0.091338
# 2130   9.756102    0.000869    0.091327
# 2131   9.756780    0.000867    0.091316
# 2132   9.757454    0.000865    0.091306
#
# [2133 rows x 3 columns]

# %%
from utils.utils import plot_sim_df

plot_sim_df(sim_df, "./outputs")
# Out:
# IAE Cross track: 267.3790357006965, IAE Vertical track: 7821.301739524127
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
